# %%
import numpy as np

arr = np.array([[1,2,3,],[4,6,5],[7,8,9]])
print(arr.shape)    #show dimentions
print(arr.dtype)    #show type
print(arr.size)     #size
print(arr.ndim)     #total dimentions
# Out:
# (3, 3)
# int64
# 9
# 2
